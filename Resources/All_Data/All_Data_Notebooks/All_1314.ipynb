# %%
#Add the Pandas dependency
import pandas as pd

# %%
#Files to load
grad_enroll=pd.read_csv('../../Grad_Enroll/grad_enroll_1314.csv')
grad_enroll
# Out:
#             CDS_CODE                            DISTRICT  ETHNIC  GR_12  \
# 0      1100170000000  Alameda County Office of Education       0      1
# 1      1100170000000  Alameda County Office of Education       1      3
# 2      1100170000000  Alameda County Office of Education       2     13
# 3      1100170000000  Alameda County Office of Education       3      2
# 4      1100170000000  Alameda County Office of Education       4      3
# ...              ...                                 ...     ...    ...
# 3788  58727700000000                Wheatland Union High       4      2
# 3789  58727700000000                Wheatland Union High       5     45
# 3790  58727700000000                Wheatland Union High       6      3
# 3791  58727700000000                Wheatland Union High       7    103
# 3792  58727700000000                Wheatland Union High       9     16
#
#       ENR_TOTAL  GRADS  UC_GRADS
# 0            29      4         0
# 1            23      2         2
# ...

# %%
finance_data=pd.read_csv("../../Finance Data/Finance_Data/Finance_1314.csv")
finance_data
# Out:
#             CDS_CODE  District_Code  Function_Code  \
# 0      1100170000000          10017           2100
# 1      1100170000000          10017           5900
# 2      1100170000000          10017           7110
# 3      1100170000000          10017           9200
# 4      1404020000000          40402           2100
# ...              ...            ...            ...
# 4019  58727510000000          72751           9200
# 4020  58727690000000          72769           2100
# 4021  58727690000000          72769           4200
# 4022  58727690000000          72769           8110
# 4023  58727690000000          72769           9200
#
#                                                Function       Amount
# 0     Classified Instructional Salaries             ...  10945394.96
# 1     Communications                                ...   1087658.80
# 2     Tuition for Instruction Under Interdistrict At...    248516.98
# 3     Accounts Receivable                           ...    992168.53
# ...

# %%
grad_enroll_finance=pd.merge(grad_enroll, finance_data, on=['CDS_CODE'])
grad_enroll_finance
# Out:
#             CDS_CODE                            DISTRICT  ETHNIC  GR_12  \
# 0      1100170000000  Alameda County Office of Education       0      1
# 1      1100170000000  Alameda County Office of Education       0      1
# 2      1100170000000  Alameda County Office of Education       0      1
# 3      1100170000000  Alameda County Office of Education       0      1
# 4      1100170000000  Alameda County Office of Education       1      3
# ...              ...                                 ...     ...    ...
# 2917  57727100000000              Woodland Joint Unified       9      7
# 2918  57727100000000              Woodland Joint Unified       9      7
# 2919  57727100000000              Woodland Joint Unified       9      7
# 2920  57727100000000              Woodland Joint Unified       9      7
# 2921  57727100000000              Woodland Joint Unified       9      7
#
#       ENR_TOTAL  GRADS  UC_GRADS  District_Code  Function_Code  \
# ...

# %%
grad_enroll_finance.to_csv('../All_Data_Data/All_1314.csv')
