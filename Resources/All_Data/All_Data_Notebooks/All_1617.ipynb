# %%
#Add the Pandas dependency
import pandas as pd

# %%
#Files to load
grad_enroll=pd.read_csv('../../Grad_Enroll/grad_enroll_1617.csv')
grad_enroll
# Out:
#         CDS_CODE  ETHNIC  GR_12  ENR_TOTAL  GRADS  UC_GRADS
# 0  1751010000000       2    434       1835      3         0
# 1  1751010000000       5    114        479      1         0
# 2  1751010000000       7    629       2315     11         1
# 3  7617540000000       5    982       3983      1         0
# 4  7617960000000       5   1266       6630      6         0
# 5  7617960000000       6    436       1913      5         0
# 6  7617960000000       7    199        958      3         0

# %%
finance_data=pd.read_csv("../../Finance Data/Finance_Data/Finance_1617.csv")
finance_data
# Out:
#             CDS_CODE  District_Code  Function_Code  \
# 0      1100170000000          10017           2100
# 1      1100170000000          10017           5400
# 2      1100170000000          10017           5900
# 3      1100170000000          10017           7110
# 4      1100170000000          10017           9200
# ...              ...            ...            ...
# 4145  58727690000000          72769           2100
# 4146  58727690000000          72769           4100
# 4147  58727690000000          72769           4200
# 4148  58727690000000          72769           8110
# 4149  58727690000000          72769           9200
#
#                                                Function       Amount
# 0     Classified Instructional Salaries             ...  13585392.15
# 1     Insurance                                     ...       649.33
# 2     Communications                                ...    798095.96
# 3     Tuition for Instruction Under Interdistrict At...    464664.55
# ...

# %%
grad_enroll_finance=pd.merge(grad_enroll, finance_data, on=['CDS_CODE'])
grad_enroll_finance
# Out:
#          CDS_CODE  ETHNIC  GR_12  ENR_TOTAL  GRADS  UC_GRADS  District_Code  \
# 0   1751010000000       2    434       1835      3         0          75101
# 1   1751010000000       2    434       1835      3         0          75101
# 2   1751010000000       2    434       1835      3         0          75101
# 3   1751010000000       5    114        479      1         0          75101
# 4   1751010000000       5    114        479      1         0          75101
# 5   1751010000000       5    114        479      1         0          75101
# 6   1751010000000       7    629       2315     11         1          75101
# 7   1751010000000       7    629       2315     11         1          75101
# 8   1751010000000       7    629       2315     11         1          75101
# 9   7617540000000       5    982       3983      1         0          61754
# 10  7617540000000       5    982       3983      1         0          61754
# ...

# %%
grad_enroll_finance.to_csv('../All_Data_Data/All_1617')
