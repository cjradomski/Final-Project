# %%
#add dependencies
import pandas as pd

# %%
#Load file
grad_df=pd.read_csv("../Graduation '13-'14.zip")
grad_df.head()
# Out:
#        CDS_CODE  ETHNIC GENDER  GRADS  UC_GRADS  YEAR
# 0  1.100170e+12       3      M      1         0  1314
# 1  1.100170e+12       6      F      3         0  1314
# 2  1.100170e+12       5      F      4         1  1314
# 3  1.100170e+12       2      M      4         1  1314
# 4  1.100170e+12       5      M      5         0  1314

# %%
#Determine any missing values
grad_df.dropna()
grad_df.count()
# Out:
# CDS_CODE    20746
# ETHNIC      20746
# GENDER      20746
# GRADS       20746
# UC_GRADS    20746
# YEAR        20746
# dtype: int64

# %%
#Determine data types
grad_df.dtypes
# Out:
# CDS_CODE    float64
# ETHNIC        int64
# GENDER       object
# GRADS         int64
# UC_GRADS      int64
# YEAR          int64
# dtype: object

# %%
#keep wanted columns
grad_df=grad_df[['CDS_CODE','ETHNIC','GRADS','UC_GRADS']]
grad_df
# Out:
#            CDS_CODE  ETHNIC  GRADS  UC_GRADS
# 0      1.100170e+12       3      1         0
# 1      1.100170e+12       6      3         0
# 2      1.100170e+12       5      4         1
# 3      1.100170e+12       2      4         1
# 4      1.100170e+12       5      5         0
# ...             ...     ...    ...       ...
# 20741  5.872770e+13       2      2         0
# 20742  5.872770e+13       4      1         1
# 20743  5.872770e+13       5     24        16
# 20744  5.872770e+13       2      3         2
# 20745  5.872770e+13       3      1         1
#
# [20746 rows x 4 columns]

# %%
#convert CDS_CODE to int
grad_df['CDS_CODE'] = grad_df['CDS_CODE'].astype('int64') 
grad_df.head(11)
# Out:
#          CDS_CODE  ETHNIC  GRADS  UC_GRADS
# 0   1100170000000       3      1         0
# 1   1100170000000       6      3         0
# 2   1100170000000       5      4         1
# 3   1100170000000       2      4         1
# 4   1100170000000       5      5         0
# 5   1100170000000       7     29         7
# 6   1100170000000       7     10         3
# 7   1100170000000       0      2         0
# 8   1100170000000       2      6         4
# 9   1100170000000       4      1         1
# 10  1100170000000       6     13        13

# %%
#Group and sort by CDS and ethnic
grad_df=grad_df.groupby(['CDS_CODE','ETHNIC']).sum()
grad_df=grad_df.sort_values(by=['CDS_CODE','ETHNIC'])
grad_df.head(11)
# Out:
#                       GRADS  UC_GRADS
# CDS_CODE      ETHNIC
# 1100170000000 0           2         0
#               1           1         1
#               2          13         5
#               3           1         0
#               4           6         3
#               5          98        44
#               6          67        33
#               7          50        10
#               9           5         1
# 1316170000000 2           5         0
#               5          15         0

# %%
grad_df.to_csv('../Grad_Data/grad_1314.csv')

# %% [markdown]
# ## Enrollment Data

# %%
#load enrollment data
clean_enroll=pd.read_csv("../../Enrollment Data/Enroll_Data/clean_enroll13_14.csv")
clean_enroll
# Out:
#              CDS_CODE  ETHNIC GENDER  GR_12  ENR_TOTAL
# 0       1100170000000       0      F      1         12
# 1       1100170000000       0      M      0         17
# 2       1100170000000       1      F      2         14
# 3       1100170000000       1      M      1          9
# 4       1100170000000       2      F      6        197
# ...               ...     ...    ...    ...        ...
# 14028  58727700000000       6      M      3          8
# 14029  58727700000000       7      F     53        203
# 14030  58727700000000       7      M     50        212
# 14031  58727700000000       9      F     12         34
# 14032  58727700000000       9      M      4         38
#
# [14033 rows x 5 columns]

# %%
#group and sort by ethnic
clean_enroll=clean_enroll[['CDS_CODE','ETHNIC','GR_12','ENR_TOTAL']]
#clean_enroll_no_ethnic=clean_enroll[['CDS_CODE','GR_12','ENR_TOTAL']]
clean_enroll=clean_enroll.groupby(['CDS_CODE','ETHNIC']).sum()
clean_enroll=clean_enroll.sort_values(by=['CDS_CODE','ETHNIC'])
clean_enroll.head(11)
# Out:
#                       GR_12  ENR_TOTAL
# CDS_CODE      ETHNIC
# 1100170000000 0           1         29
#               1           3         23
#               2          13        395
#               3           2         33
#               4           3         42
#               5         102        816
#               6          62        597
#               7          29        875
#               9           7        152
# 1100180000000 0           0          0
#               1           0         44

# %%
#merge data
enroll_grad_df=pd.merge(clean_enroll, grad_df, on =['CDS_CODE','ETHNIC'])
enroll_grad_df.head(11)
# Out:
#                       GR_12  ENR_TOTAL  GRADS  UC_GRADS
# CDS_CODE      ETHNIC
# 1100170000000 0           1         29      2         0
#               1           3         23      1         1
#               2          13        395     13         5
#               3           2         33      1         0
#               4           3         42      6         3
#               5         102        816     98        44
#               6          62        597     67        33
#               7          29        875     50        10
#               9           7        152      5         1
# 1316170000000 2           8         28      5         0
#               5          35        181     15         0

# %%
enroll_grad_df.count()
# Out:
# GR_12        3350
# ENR_TOTAL    3350
# GRADS        3350
# UC_GRADS     3350
# dtype: int64

# %%
enroll_grad_df.to_csv('../../Grad_Enroll/grad_enroll_1314.csv')
