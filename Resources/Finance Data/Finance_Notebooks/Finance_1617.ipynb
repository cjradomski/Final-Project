# %%
#add depedencies
import pandas as pd

# %% [markdown]
# ## Cleaning Budget Data

# %%
#Load finance file
data_df=pd.read_csv("../School Budget Data '16-'17.zip",
                       names=['County_Code','District_Code','School_Code','Fiscal_Year',
                                  'Period','Colcode','Account_Code','Fund_Code','Resource_Code',
                                  'Project_Year','Goal','Function_Code','Object_Code','Amount'])
data_df
# Out:
# C:\Users\hhngu\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          County_Code  District_Code  School_Code  Fiscal_Year Period Colcode  \
# 0                  1          10017            0         2016   A       BA
# 1                  1          10017            0         2016   A       BA
# 2                  1          10017            0         2016   A       BA
# 3                  1          10017            0         2016   A       BA
# 4                  1          10017            0         2016   A       BA
# ...              ...            ...          ...          ...    ...     ...
# 1250414           58          72769            0         2016   A       BA
# 1250415           58          72769            0         2016   A       BA
# 1250416           58          72769            0         2016   A       BA
# 1250417           58          72769            0         2016   A       BA
# 1250418           58          72769            0         2016   A       BA
#
#                 Account_Code  Fund_Code  Resource_Code Project_Year  Goal  \
# 0        0100000000000008011          1              0            0  0000
# 1        0100000000000008021          1              0            0  0000
# 2        0100000000000008029          1              0            0  0000
# 3        0100000000000008041          1              0            0  0000
# 4        0100000000000008042          1              0            0  0000
# ...                      ...        ...            ...          ...   ...
# 1250414  7300000000000009110         73              0            0  0000
# 1250415  7300000000000009790         73              0            0  0000
# 1250416  7300000000000009791         73              0            0  0000
# 1250417  730000000000000979Z         73              0            0  0000
# 1250418  7300000000027005800         73              0            0  0000
#
#          Function_Code Object_Code       Amount
# 0                    0        8011   3968003.13
# 1                    0        8021    120934.71
# 2                    0        8029      1143.95
# 3                    0        8041  14718142.47
# 4                    0        8042    809779.10
# ...                ...         ...          ...
# 1250414              0        9110     76402.84
# 1250415              0        9790     76402.84
# 1250416              0        9791     77182.61
# 1250417              0        979Z     76402.84
# 1250418           2700        5800      3100.00
#
# [1250419 rows x 14 columns]

# %%
#Determine any missing values 
data_df.dropna()
data_df.count()
# Out:
# County_Code      1250419
# District_Code    1250419
# School_Code      1250419
# Fiscal_Year      1250419
# Period           1250419
# Colcode          1250419
# Account_Code     1250419
# Fund_Code        1250419
# Resource_Code    1250419
# Project_Year     1250419
# Goal             1250419
# Function_Code    1250419
# Object_Code      1250419
# Amount           1250419
# dtype: int64

# %%
data_df.dtypes
# Out:
# County_Code        int64
# District_Code      int64
# School_Code        int64
# Fiscal_Year        int64
# Period            object
# Colcode           object
# Account_Code      object
# Fund_Code          int64
# Resource_Code      int64
# Project_Year      object
# Goal              object
# Function_Code      int64
# Object_Code       object
# Amount           float64
# dtype: object

# %%
#Select desired columns
clean_data_df=data_df[['County_Code','District_Code','School_Code','Function_Code','Amount']]
clean_data_df
# Out:
#          County_Code  District_Code  School_Code  Function_Code       Amount
# 0                  1          10017            0              0   3968003.13
# 1                  1          10017            0              0    120934.71
# 2                  1          10017            0              0      1143.95
# 3                  1          10017            0              0  14718142.47
# 4                  1          10017            0              0    809779.10
# ...              ...            ...          ...            ...          ...
# 1250414           58          72769            0              0     76402.84
# 1250415           58          72769            0              0     76402.84
# 1250416           58          72769            0              0     77182.61
# 1250417           58          72769            0              0     76402.84
# 1250418           58          72769            0           2700      3100.00
#
# [1250419 rows x 5 columns]

# %%
#Concatenate district, county and school code to get CDS CODE
clean_data_df['District']=clean_data_df['District_Code'] * 10000000
clean_data_df['County']=clean_data_df['County_Code'] * 1000000000000
clean_data_df
# Out:
# C:\Users\hhngu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hhngu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          County_Code  District_Code  School_Code  Function_Code       Amount  \
# 0                  1          10017            0              0   3968003.13
# 1                  1          10017            0              0    120934.71
# 2                  1          10017            0              0      1143.95
# 3                  1          10017            0              0  14718142.47
# 4                  1          10017            0              0    809779.10
# ...              ...            ...          ...            ...          ...
# 1250414           58          72769            0              0     76402.84
# 1250415           58          72769            0              0     76402.84
# 1250416           58          72769            0              0     77182.61
# 1250417           58          72769            0              0     76402.84
# 1250418           58          72769            0           2700      3100.00
#
#              District          County
# 0        100170000000   1000000000000
# 1        100170000000   1000000000000
# 2        100170000000   1000000000000
# 3        100170000000   1000000000000
# 4        100170000000   1000000000000
# ...               ...             ...
# 1250414  727690000000  58000000000000
# 1250415  727690000000  58000000000000
# 1250416  727690000000  58000000000000
# 1250417  727690000000  58000000000000
# 1250418  727690000000  58000000000000
#
# [1250419 rows x 7 columns]

# %%
clean_data_df['CDS_CODE']=clean_data_df['District'] + clean_data_df['County'] + clean_data_df['School_Code']
clean_data_df
# Out:
# C:\Users\hhngu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          County_Code  District_Code  School_Code  Function_Code       Amount  \
# 0                  1          10017            0              0   3968003.13
# 1                  1          10017            0              0    120934.71
# 2                  1          10017            0              0      1143.95
# 3                  1          10017            0              0  14718142.47
# 4                  1          10017            0              0    809779.10
# ...              ...            ...          ...            ...          ...
# 1250414           58          72769            0              0     76402.84
# 1250415           58          72769            0              0     76402.84
# 1250416           58          72769            0              0     77182.61
# 1250417           58          72769            0              0     76402.84
# 1250418           58          72769            0           2700      3100.00
#
#              District          County        CDS_CODE
# 0        100170000000   1000000000000   1100170000000
# 1        100170000000   1000000000000   1100170000000
# 2        100170000000   1000000000000   1100170000000
# 3        100170000000   1000000000000   1100170000000
# 4        100170000000   1000000000000   1100170000000
# ...               ...             ...             ...
# 1250414  727690000000  58000000000000  58727690000000
# 1250415  727690000000  58000000000000  58727690000000
# 1250416  727690000000  58000000000000  58727690000000
# 1250417  727690000000  58000000000000  58727690000000
# 1250418  727690000000  58000000000000  58727690000000
#
# [1250419 rows x 8 columns]

# %%
clean_data=clean_data_df[['CDS_CODE','District_Code','Function_Code','Amount']]
clean_data
# Out:
#                CDS_CODE  District_Code  Function_Code       Amount
# 0         1100170000000          10017              0   3968003.13
# 1         1100170000000          10017              0    120934.71
# 2         1100170000000          10017              0      1143.95
# 3         1100170000000          10017              0  14718142.47
# 4         1100170000000          10017              0    809779.10
# ...                 ...            ...            ...          ...
# 1250414  58727690000000          72769              0     76402.84
# 1250415  58727690000000          72769              0     76402.84
# 1250416  58727690000000          72769              0     77182.61
# 1250417  58727690000000          72769              0     76402.84
# 1250418  58727690000000          72769           2700      3100.00
#
# [1250419 rows x 4 columns]

# %%
clean_data = clean_data[clean_data.Function_Code != 0]
clean_data
# Out:
#                CDS_CODE  District_Code  Function_Code     Amount
# 37        1100170000000          10017           2490     614.23
# 38        1100170000000          10017           2490   10834.18
# 39        1100170000000          10017           2490  -60736.15
# 40        1100170000000          10017           3140    4493.56
# 41        1100170000000          10017           3140    3858.89
# ...                 ...            ...            ...        ...
# 1250391  58727690000000          72769           9100   29043.93
# 1250392  58727690000000          72769           9100   66441.10
# 1250410  58727690000000          72769           9100  127702.92
# 1250411  58727690000000          72769           9100   50000.00
# 1250418  58727690000000          72769           2700    3100.00
#
# [981408 rows x 4 columns]

# %%
clean_data = clean_data[clean_data.Amount >= 0]
clean_data
# Out:
#                CDS_CODE  District_Code  Function_Code     Amount
# 37        1100170000000          10017           2490     614.23
# 38        1100170000000          10017           2490   10834.18
# 40        1100170000000          10017           3140    4493.56
# 41        1100170000000          10017           3140    3858.89
# 42        1100170000000          10017           3140     388.96
# ...                 ...            ...            ...        ...
# 1250391  58727690000000          72769           9100   29043.93
# 1250392  58727690000000          72769           9100   66441.10
# 1250410  58727690000000          72769           9100  127702.92
# 1250411  58727690000000          72769           9100   50000.00
# 1250418  58727690000000          72769           2700    3100.00
#
# [958340 rows x 4 columns]

# %% [markdown]
# ## Cleaning Objects.CSV

# %%
#load object budget categories
#object_df=pd.read_csv("../Objects (Budget Categories).csv",
                   #  names=['Code','Title'])
#object_df

# %%
#Drop na and count to verify
#object_df.dropna()
#object_df.count()

# %%
#Delete extra columns
#object_df=object_df[['Code','Title']]
#object_df

# %%
#Verify datatypes
#object_df.dtypes

# %%
#Clarify what is null, if any
#object_df1=object_df[object_df.isna().any(axis=1)]
#object_df1

# %%
#Drop Null
#object_df=object_df.dropna()
#object_df

# %%
#Rename column
#object_df=object_df.rename(columns={"Code":"Object_Code","Title":"Object"})
#object_df

# %%
#Merge object table with budget table
#clean_data=pd.merge(clean_data, object_df, on =['Object_Code'])
#clean_data

# %%
#Drop unnecessary columns
#clean_data=clean_data[['CDS_CODE','Object','Function_Code','Amount']]
#clean_data

# %% [markdown]
# ## Cleaning Function.CSV

# %%
#load object budget categories
function_df=pd.read_csv("../Objects (Budget Categories).csv",
                     names=['Function_Code','Function'])
#object_df
#load function csv
#function_df=pd.read_csv("../Function (Budget Categories).csv")
function_df
# Out:
#     Function_Code                                           Function
# 0            1100  Certificated Teachers' Salaries               ...
# 1            1200  Certificated Pupil Support Salaries           ...
# 2            1300  Certificated Supervisors' and Administrators' ...
# 3            1900  Other Certificated Salaries                   ...
# 4            2100  Classified Instructional Salaries             ...
# ..            ...                                                ...
# 233          9793  Audit Adjustments                             ...
# 234          9795  Other Restatements                            ...
# 235          9796  Net Investment in Capital Assets              ...
# 236          9797  Restricted Net Position                       ...
# 237          979Z  EFB (Calculated)                              ...
#
# [238 rows x 2 columns]

# %%
#keep necessary columns
function_df=function_df[['Function_Code','Function']]
function_df
# Out:
#     Function_Code                                           Function
# 0            1100  Certificated Teachers' Salaries               ...
# 1            1200  Certificated Pupil Support Salaries           ...
# 2            1300  Certificated Supervisors' and Administrators' ...
# 3            1900  Other Certificated Salaries                   ...
# 4            2100  Classified Instructional Salaries             ...
# ..            ...                                                ...
# 233          9793  Audit Adjustments                             ...
# 234          9795  Other Restatements                            ...
# 235          9796  Net Investment in Capital Assets              ...
# 236          9797  Restricted Net Position                       ...
# 237          979Z  EFB (Calculated)                              ...
#
# [238 rows x 2 columns]

# %%
function_df=function_df.drop(function_df.index[237])
function_df
# Out:
#     Function_Code                                           Function
# 0            1100  Certificated Teachers' Salaries               ...
# 1            1200  Certificated Pupil Support Salaries           ...
# 2            1300  Certificated Supervisors' and Administrators' ...
# 3            1900  Other Certificated Salaries                   ...
# 4            2100  Classified Instructional Salaries             ...
# ..            ...                                                ...
# 232          9791  Beginning Fund Balance                        ...
# 233          9793  Audit Adjustments                             ...
# 234          9795  Other Restatements                            ...
# 235          9796  Net Investment in Capital Assets              ...
# 236          9797  Restricted Net Position                       ...
#
# [237 rows x 2 columns]

# %%
#determine which are null
function_df1=function_df[function_df.isna().any(axis=1)]
function_df1
# Out:
# Empty DataFrame
# Columns: [Function_Code, Function]
# Index: []

# %%
#drop NA
function_df_clean=function_df.dropna()
function_df_clean
# Out:
#     Function_Code                                           Function
# 0            1100  Certificated Teachers' Salaries               ...
# 1            1200  Certificated Pupil Support Salaries           ...
# 2            1300  Certificated Supervisors' and Administrators' ...
# 3            1900  Other Certificated Salaries                   ...
# 4            2100  Classified Instructional Salaries             ...
# ..            ...                                                ...
# 232          9791  Beginning Fund Balance                        ...
# 233          9793  Audit Adjustments                             ...
# 234          9795  Other Restatements                            ...
# 235          9796  Net Investment in Capital Assets              ...
# 236          9797  Restricted Net Position                       ...
#
# [237 rows x 2 columns]

# %%
#rough estimate
function_df_clean.count()
# Out:
# Function_Code    237
# Function         237
# dtype: int64

# %%
#verify datatypes
clean_data.dtypes
# Out:
# CDS_CODE           int64
# District_Code      int64
# Function_Code      int64
# Amount           float64
# dtype: object

# %%
#change datatypes to match in order to merge
clean_data['Function_Code'] = clean_data['Function_Code'].astype('int64')
function_df_clean['Function_Code']= function_df_clean['Function_Code'].astype('int64')
# Out:
# C:\Users\hhngu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#merge
func_df=pd.merge(clean_data, function_df_clean, on=['Function_Code'])
func_df
# Out:
#               CDS_CODE  District_Code  Function_Code    Amount  \
# 0        1100170000000          10017           7110  69545.39
# 1        1100170000000          10017           7110  62604.36
# 2        1100170000000          10017           7110   9484.86
# 3        1100170000000          10017           7110   9818.35
# 4        1100170000000          10017           7110  51176.90
# ...                ...            ...            ...       ...
# 123530  57105790000000          10579           7350   3861.96
# 123531  57105790000000          10579           7350   1221.17
# 123532  57105790000000          10579           7350   2670.52
# 123533  57105790000000          10579           7350   3083.66
# 123534  57105790000000          10579           7350    980.00
#
#                                                  Function
# 0       Tuition for Instruction Under Interdistrict At...
# 1       Tuition for Instruction Under Interdistrict At...
# 2       Tuition for Instruction Under Interdistrict At...
# 3       Tuition for Instruction Under Interdistrict At...
# 4       Tuition for Instruction Under Interdistrict At...
# ...                                                   ...
# 123530  Transfers of Indirect Costs - Interfund       ...
# 123531  Transfers of Indirect Costs - Interfund       ...
# 123532  Transfers of Indirect Costs - Interfund       ...
# 123533  Transfers of Indirect Costs - Interfund       ...
# 123534  Transfers of Indirect Costs - Interfund       ...
#
# [123535 rows x 5 columns]

# %%
#Keep necessary columns
final_data=func_df[['CDS_CODE','District_Code','Function_Code','Function','Amount']]
final_data
# Out:
#               CDS_CODE  District_Code  Function_Code  \
# 0        1100170000000          10017           7110
# 1        1100170000000          10017           7110
# 2        1100170000000          10017           7110
# 3        1100170000000          10017           7110
# 4        1100170000000          10017           7110
# ...                ...            ...            ...
# 123530  57105790000000          10579           7350
# 123531  57105790000000          10579           7350
# 123532  57105790000000          10579           7350
# 123533  57105790000000          10579           7350
# 123534  57105790000000          10579           7350
#
#                                                  Function    Amount
# 0       Tuition for Instruction Under Interdistrict At...  69545.39
# 1       Tuition for Instruction Under Interdistrict At...  62604.36
# 2       Tuition for Instruction Under Interdistrict At...   9484.86
# 3       Tuition for Instruction Under Interdistrict At...   9818.35
# 4       Tuition for Instruction Under Interdistrict At...  51176.90
# ...                                                   ...       ...
# 123530  Transfers of Indirect Costs - Interfund       ...   3861.96
# 123531  Transfers of Indirect Costs - Interfund       ...   1221.17
# 123532  Transfers of Indirect Costs - Interfund       ...   2670.52
# 123533  Transfers of Indirect Costs - Interfund       ...   3083.66
# 123534  Transfers of Indirect Costs - Interfund       ...    980.00
#
# [123535 rows x 5 columns]

# %%
#Organize data
final_data=final_data.groupby(['CDS_CODE','District_Code','Function_Code','Function']).sum()
final_data
# Out:
#                                                                                                     Amount
# CDS_CODE       District_Code Function_Code Function
# 1100170000000  10017         2100          Classified Instructional Salaries              ...  13585392.15
#                              5400          Insurance                                      ...       649.33
#                              5900          Communications                                 ...    798095.96
#                              7110          Tuition for Instruction Under Interdistrict Att...    464664.55
#                              9200          Accounts Receivable                            ...   2234177.64
# ...                                                                                                    ...
# 58727690000000 72769         2100          Classified Instructional Salaries              ...    170158.50
#                              4100          Approved Textbooks and Core Curricula Materials...     11085.55
#                              4200          Books and Other Reference Materials            ...    185890.37
#                              8110          Maintenance and Operations (Public Law 81-874) ...    299519.02
#                              9200          Accounts Receivable                            ...    204169.44
#
# [4150 rows x 1 columns]

# %%
final_data.to_csv('../Finance_Data/Finance_1617.csv')
